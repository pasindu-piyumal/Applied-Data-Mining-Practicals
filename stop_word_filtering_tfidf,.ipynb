# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords   
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
with open('C:\\Users\\USER\\OneDrive\\Documents\\University\\Year_2_Semester_2\\Applied_Data_Mining\\Practicals\\documents\\doc1_ai.txt') as f:
    doc1 = f.read()

with open('C:\\Users\\USER\\OneDrive\\Documents\\University\\Year_2_Semester_2\\Applied_Data_Mining\\Practicals\\documents\\doc2_cloud.txt') as f:
    doc2 = f.read()

with open('C:\\Users\\USER\\OneDrive\\Documents\\University\\Year_2_Semester_2\\Applied_Data_Mining\\Practicals\\documents\\doc3_security.txt') as f:
    doc3 = f.read()

# %%
words_doc1 = word_tokenize(doc1)
words_doc2 = word_tokenize(doc2)
words_doc3 = word_tokenize(doc3)

# %%
stop_words = set(stopwords.words('english'))
filtered_doc1 = [word for word in words_doc1 if word.lower() not in stop_words]
filtered_doc2 = [word for word in words_doc2 if word.lower() not in stop_words]
filtered_doc3 = [word for word in words_doc3 if word.lower() not in stop_words]

# %%
print("Original Documnet 1: ", words_doc1)
print("Filtered Document 1: ", filtered_doc1)
print("Original Documnet 2: ", words_doc2)
print("Filtered Document 2: ", filtered_doc2)
print("Original Documnet 3: ", words_doc3)
print("Filtered Document 3: ", filtered_doc3)
# Out:
# Original Documnet 1:  ['Artificial', 'intelligence', 'is', 'changing', 'the', 'world', '.', 'Robots', 'use', 'artificial', 'intelligence', 'to', 'learn', 'and', 'solve', 'complex', 'problems', '.', 'The', 'future', 'of', 'technology', 'depends', 'on', 'artificial', 'intelligence', '.']
# Filtered Document 1:  ['Artificial', 'intelligence', 'changing', 'world', '.', 'Robots', 'use', 'artificial', 'intelligence', 'learn', 'solve', 'complex', 'problems', '.', 'future', 'technology', 'depends', 'artificial', 'intelligence', '.']
# Original Documnet 2:  ['Cloud', 'computing', 'allows', 'us', 'to', 'store', 'massive', 'amounts', 'of', 'data', '.', 'Data', 'science', 'uses', 'this', 'data', 'to', 'predict', 'future', 'trends', '.', 'The', 'future', 'of', 'data', 'storage', 'is', 'in', 'the', 'cloud', '.']
# ...

# %%
list = [filtered_doc1, filtered_doc2, filtered_doc3]

# %%
tfidf = TfidfVectorizer()
result = tfidf.fit_transform(" ".join(i) for i in list)
feature_names = tfidf.get_feature_names_out()
df = pd.DataFrame(result.toarray(), columns=feature_names)

# %%
df
# Out:
#    advanced    allows   amounts  artificial  changing    cloud   complex  \
# 0  0.000000  0.000000  0.000000    0.563448  0.187816  0.00000  0.187816
# 1  0.000000  0.175695  0.175695    0.000000  0.000000  0.35139  0.000000
# 2  0.221682  0.000000  0.000000    0.000000  0.000000  0.00000  0.000000
#
#    computing  cybersecurity      data  ...     solve   storage     store  \
# 0   0.000000       0.000000  0.000000  ...  0.187816  0.000000  0.000000
# 1   0.175695       0.000000  0.702779  ...  0.000000  0.175695  0.175695
# 2   0.000000       0.665046  0.000000  ...  0.000000  0.000000  0.000000
#
#      strong  technology    trends        us       use      uses     world
# 0  0.000000    0.187816  0.000000  0.000000  0.187816  0.000000  0.187816
# 1  0.000000    0.000000  0.175695  0.175695  0.000000  0.175695  0.000000
# 2  0.221682    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [3 rows x 38 columns]
